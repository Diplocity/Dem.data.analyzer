# %% [markdown]
# <a href="https://colab.research.google.com/github/Diplocity/Dem.data.analyzer/blob/main/CandlestickBMWchart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import plotly.graph_objs as go

# Fetching data from January 1, 2023, to June 30, 2024
start_date = "2023-01-01"
end_date = "2024-06-30"

# BMW ticker symbol on Yahoo Finance
ticker = 'BMW.DE'

# Fetch the stock data
try:
    print("Fetching data...")
    bmw_data = yf.download(ticker, start=start_date, end=end_date)
    if bmw_data.empty:
        print("No data fetched. Check the ticker symbol and date range.")
    else:
        print(f"Data fetched successfully. Number of records: {len(bmw_data)}")
except Exception as e:
    print(f"Error fetching data: {e}")
    raise

# ==============================
# Candlestick Chart Section
# ==============================
try:
    print("Creating candlestick chart...")
    fig = go.Figure(data=[go.Candlestick(x=bmw_data.index,
                                         open=bmw_data['Open'],
                                         high=bmw_data['High'],
                                         low=bmw_data['Low'],
                                         close=bmw_data['Close'])])

    # Add titles and labels to the candlestick chart
    fig.update_layout(title='BMW Stock Price (January 2023 - June 2024)',
                      yaxis_title='Stock Price (EUR)',
                      xaxis_title='Date')

    # ==============================
    # Range Slider Section
    # ==============================
    fig.update_layout(
        xaxis=dict(
            rangeslider=dict(
                visible=True  # This enables the range slider
            ),
            type="date"  # Ensures the x-axis is treated as date values
        )
    )

    # Display the plot in the notebook
    print("Displaying the chart in the notebook...")
    fig.show()

except Exception as e:
    print(f"Error creating or displaying the chart: {e}")
    raise

print("Script finished successfully.")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Fetching data...
# Data fetched successfully. Number of records: 381
# Creating candlestick chart...
# Displaying the chart in the notebook...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="98dc9478-1ba2-43de-9e9b-969c3abfff69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98dc9478-1ba2-43de-9e9b-969c3abfff69")) {                    Plotly.newPlot(                        "98dc9478-1ba2-43de-9e9b-969c3abfff69",                        [{"close":[85.80000305175781,85.83000183105469,87.87999725341797,88.94999694824219,89.52999877929688,89.9800033569336,90.5199966430664,91.77999877929688,93.22000122070312,91.73999786376953,91.83999633789062,91.9800033569336,91.43000030517578,90.0199966430664,89.97000122070312,91.52999877929688,91.79000091552734,91.79000091552734,92.3499984741211,92.3499984741211,91.4800033569336,93.2300033569336,95.2699966430664,97.79000091552734,97.58000183105469,97.05999755859375,97.4000015258789,97.56999969482422,99.45999908447266,97.7699966430664,97.61000061035156,97.73999786376953,99.18000030517578,99.23999786376953,99.75,99.66999816894531,98.69999694824219,98.43000030517578,99.6500015258789,97.19000244140625,98.16000366210938,97